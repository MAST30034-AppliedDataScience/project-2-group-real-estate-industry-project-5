# %%
import pandas as pd
import re

# %%
# LOAD csv
file_path = '../data/curated/properties_with_closest_shopping_centers.csv'  
df = pd.read_csv(file_path)

# %%
columns_to_drop = ['Closest Station', 'Closest School', 'Closest Shopping Center']
df_cleaned = df.drop(columns=columns_to_drop)

# %%
df_cleaned
# Out:
#                                  Property Name  Property Latitude  \
# 0           6/137 Coppin St, Richmond VIC 3121         -37.820283
# 1        205/6 Joseph Road, Footscray VIC 3011         -37.798238
# 2             8/7 Docker St, Richmond VIC 3121         -37.823681
# 3         8/51 Kooyong Road, Armadale VIC 3143         -37.862342
# 4     10/54 Rockley Road, South Yarra VIC 3141         -37.835164
# ...                                        ...                ...
# 3078      176 Scotchmans Rd, Drysdale VIC 3222         -38.149923
# 3079       485 Punt Road, South Yarra VIC 3141         -37.830086
# 3080           4 Vital drive, Tarneit VIC 3029         -37.858304
# 3081    14 Sheffield Way, Keysborough VIC 3173         -38.000807
# 3082      4 Ocean Park Drive, Marengo VIC 3233         -38.771375
#
#       Property Longitude  Distance (km)            cost_text  \
# 0             145.003572       0.882026          $425 weekly
# 1             144.914181       0.990486        $510 per week
# 2             144.997096       0.308573          $425 weekly
# 3             145.019539       0.658460        $375 per week
# 4             145.000360       0.785119              $475 pw
# ...                  ...            ...                  ...
# 3078          144.626622      23.251456        $1,800 weekly
# 3079          144.987847       0.699074            $1,450.00
# 3080          144.647505       3.788183                 $550
# 3081          145.149657       4.452369            $625 / wk
# 3082          143.657868      47.991571  from $300 per night
#
#       School Distance (km)                       SA2_NAME21  \
# 0                 0.326233      Richmond (South) - Cremorne
# 1                 0.723669                        Footscray
# 2                 0.676342      Richmond (South) - Cremorne
# 3                 0.917637                         Armadale
# 4                 0.360197              South Yarra - North
# ...                    ...                              ...
# 3078              4.556564                    Portarlington
# 3079              0.321831              South Yarra - North
# 3080              1.152332  Tarneit (West) - Mount Cottrell
# 3081              0.542452              Keysborough - South
# 3082              1.994837                            Otway
#
#       Distance to Closest Shopping Center (km)
# 0                                     9.543373
# 1                                     3.431348
# 2                                    10.037550
# 3                                     6.446263
# 4                                     9.419477
# ...                                        ...
# 3078                                 29.994924
# 3079                                 10.630510
# 3080                                  5.051280
# 3081                                 13.587161
# 3082                                133.746801
#
# [3083 rows x 8 columns]

# %%
# Define function to clean
def clean_rent_price(cost_text):
    match = re.search(r'(\d+[,.]?\d*)', cost_text.replace(',', ''))
    if match:
        return float(match.group(1))
    else:
        return None

df_cleaned['weekly_rent'] = df_cleaned['cost_text'].apply(clean_rent_price)

print(df_cleaned[['cost_text', 'weekly_rent']].head())
# Out:
#        cost_text  weekly_rent
# 0    $425 weekly        425.0
# 1  $510 per week        510.0
# 2    $425 weekly        425.0
# 3  $375 per week        375.0
# 4        $475 pw        475.0

# %%
Q1 = df_cleaned['weekly_rent'].quantile(0.25)
Q3 = df_cleaned['weekly_rent'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_no_outliers = df_cleaned[(df_cleaned['weekly_rent'] >= lower_bound) & (df_cleaned['weekly_rent'] <= upper_bound)]

print(df_no_outliers[['cost_text', 'weekly_rent']].head())
# Out:
#        cost_text  weekly_rent
# 0    $425 weekly        425.0
# 1  $510 per week        510.0
# 2    $425 weekly        425.0
# 3  $375 per week        375.0
# 4        $475 pw        475.0

# %%
max_values = df_no_outliers.max()

min_values = df_no_outliers.min()

print("Max values for each column:\n", max_values)
print("\nMin values for each column:\n", min_values)
# Out:
# Max values for each column:
#  Property Name                               Park Orchards VIC 3114
# Property Latitude                                       -34.182998
# Property Longitude                                      147.646661
# Distance (km)                                           183.163879
# cost_text                                      from $300 per night
# School Distance (km)                                     12.134035
# SA2_NAME21                                              Yarraville
# Distance to Closest Shopping Center (km)                455.890734
# weekly_rent                                                 1200.0
# dtype: object
#
# Min values for each column:
#  Property Name                               1 & 2/23 Koonawarra Street, Clayton VIC 3168
# Property Latitude                                                             -38.771375
# Property Longitude                                                            142.115746
# Distance (km)                                                                   0.041703
# cost_text                                                                 $ 300 PER WEEK
# School Distance (km)                                                            0.018913
# SA2_NAME21                                                                    Abbotsford
# Distance to Closest Shopping Center (km)                                        0.163771
# weekly_rent                                                                        130.0
# dtype: object

# %%
df_no_outliers
# Out:
#                                  Property Name  Property Latitude  \
# 0           6/137 Coppin St, Richmond VIC 3121         -37.820283
# 1        205/6 Joseph Road, Footscray VIC 3011         -37.798238
# 2             8/7 Docker St, Richmond VIC 3121         -37.823681
# 3         8/51 Kooyong Road, Armadale VIC 3143         -37.862342
# 4     10/54 Rockley Road, South Yarra VIC 3141         -37.835164
# ...                                        ...                ...
# 3076      13 Adelaide St, Blairgowrie VIC 3942         -38.367311
# 3077            160 Moore rd, Sunbury VIC 3429         -37.608981
# 3080           4 Vital drive, Tarneit VIC 3029         -37.858304
# 3081    14 Sheffield Way, Keysborough VIC 3173         -38.000807
# 3082      4 Ocean Park Drive, Marengo VIC 3233         -38.771375
#
#       Property Longitude  Distance (km)            cost_text  \
# 0             145.003572       0.882026          $425 weekly
# 1             144.914181       0.990486        $510 per week
# 2             144.997096       0.308573          $425 weekly
# 3             145.019539       0.658460        $375 per week
# 4             145.000360       0.785119              $475 pw
# ...                  ...            ...                  ...
# 3076          144.785258      34.419625          $850 weekly
# 3077          144.711509       2.216868       $1100 Per Week
# 3080          144.647505       3.788183                 $550
# 3081          145.149657       4.452369            $625 / wk
# 3082          143.657868      47.991571  from $300 per night
#
#       School Distance (km)                       SA2_NAME21  \
# 0                 0.326233      Richmond (South) - Cremorne
# 1                 0.723669                        Footscray
# 2                 0.676342      Richmond (South) - Cremorne
# 3                 0.917637                         Armadale
# 4                 0.360197              South Yarra - North
# ...                    ...                              ...
# 3076              3.431329                     Point Nepean
# 3077              1.528344                  Sunbury - South
# 3080              1.152332  Tarneit (West) - Mount Cottrell
# 3081              0.542452              Keysborough - South
# 3082              1.994837                            Otway
#
#       Distance to Closest Shopping Center (km)  weekly_rent
# 0                                     9.543373        425.0
# 1                                     3.431348        510.0
# 2                                    10.037550        425.0
# 3                                     6.446263        375.0
# 4                                     9.419477        475.0
# ...                                        ...          ...
# 3076                                 54.130591        850.0
# 3077                                 11.078158       1100.0
# 3080                                  5.051280        550.0
# 3081                                 13.587161        625.0
# 3082                                133.746801        300.0
#
# [2852 rows x 9 columns]

# %%
df_no_outliers = df_no_outliers.drop(columns=['cost_text'])


df_no_outliers = df_no_outliers.rename(columns={'weekly_rent': 'cost_text'})
df_no_outliers
# Out:
#                                  Property Name  Property Latitude  \
# 0           6/137 Coppin St, Richmond VIC 3121         -37.820283
# 1        205/6 Joseph Road, Footscray VIC 3011         -37.798238
# 2             8/7 Docker St, Richmond VIC 3121         -37.823681
# 3         8/51 Kooyong Road, Armadale VIC 3143         -37.862342
# 4     10/54 Rockley Road, South Yarra VIC 3141         -37.835164
# ...                                        ...                ...
# 3076      13 Adelaide St, Blairgowrie VIC 3942         -38.367311
# 3077            160 Moore rd, Sunbury VIC 3429         -37.608981
# 3080           4 Vital drive, Tarneit VIC 3029         -37.858304
# 3081    14 Sheffield Way, Keysborough VIC 3173         -38.000807
# 3082      4 Ocean Park Drive, Marengo VIC 3233         -38.771375
#
#       Property Longitude  Distance (km)  School Distance (km)  \
# 0             145.003572       0.882026              0.326233
# 1             144.914181       0.990486              0.723669
# 2             144.997096       0.308573              0.676342
# 3             145.019539       0.658460              0.917637
# 4             145.000360       0.785119              0.360197
# ...                  ...            ...                   ...
# 3076          144.785258      34.419625              3.431329
# 3077          144.711509       2.216868              1.528344
# 3080          144.647505       3.788183              1.152332
# 3081          145.149657       4.452369              0.542452
# 3082          143.657868      47.991571              1.994837
#
#                            SA2_NAME21  \
# 0         Richmond (South) - Cremorne
# 1                           Footscray
# 2         Richmond (South) - Cremorne
# 3                            Armadale
# 4                 South Yarra - North
# ...                               ...
# 3076                     Point Nepean
# 3077                  Sunbury - South
# 3080  Tarneit (West) - Mount Cottrell
# 3081              Keysborough - South
# 3082                            Otway
#
#       Distance to Closest Shopping Center (km)  cost_text
# 0                                     9.543373      425.0
# 1                                     3.431348      510.0
# 2                                    10.037550      425.0
# 3                                     6.446263      375.0
# 4                                     9.419477      475.0
# ...                                        ...        ...
# 3076                                 54.130591      850.0
# 3077                                 11.078158     1100.0
# 3080                                  5.051280      550.0
# 3081                                 13.587161      625.0
# 3082                                133.746801      300.0
#
# [2852 rows x 8 columns]

# %%
df_no_outliers = df_no_outliers.rename(columns={'Distance (km)': 'Station Distance (km)'})

df_no_outliers = df_no_outliers.rename(columns={'cost_text': 'rent price'})

df_no_outliers
# Out:
#                                  Property Name  Property Latitude  \
# 0           6/137 Coppin St, Richmond VIC 3121         -37.820283
# 1        205/6 Joseph Road, Footscray VIC 3011         -37.798238
# 2             8/7 Docker St, Richmond VIC 3121         -37.823681
# 3         8/51 Kooyong Road, Armadale VIC 3143         -37.862342
# 4     10/54 Rockley Road, South Yarra VIC 3141         -37.835164
# ...                                        ...                ...
# 3076      13 Adelaide St, Blairgowrie VIC 3942         -38.367311
# 3077            160 Moore rd, Sunbury VIC 3429         -37.608981
# 3080           4 Vital drive, Tarneit VIC 3029         -37.858304
# 3081    14 Sheffield Way, Keysborough VIC 3173         -38.000807
# 3082      4 Ocean Park Drive, Marengo VIC 3233         -38.771375
#
#       Property Longitude  Station Distance (km)  School Distance (km)  \
# 0             145.003572               0.882026              0.326233
# 1             144.914181               0.990486              0.723669
# 2             144.997096               0.308573              0.676342
# 3             145.019539               0.658460              0.917637
# 4             145.000360               0.785119              0.360197
# ...                  ...                    ...                   ...
# 3076          144.785258              34.419625              3.431329
# 3077          144.711509               2.216868              1.528344
# 3080          144.647505               3.788183              1.152332
# 3081          145.149657               4.452369              0.542452
# 3082          143.657868              47.991571              1.994837
#
#                            SA2_NAME21  \
# 0         Richmond (South) - Cremorne
# 1                           Footscray
# 2         Richmond (South) - Cremorne
# 3                            Armadale
# 4                 South Yarra - North
# ...                               ...
# 3076                     Point Nepean
# 3077                  Sunbury - South
# 3080  Tarneit (West) - Mount Cottrell
# 3081              Keysborough - South
# 3082                            Otway
#
#       Distance to Closest Shopping Center (km)  rent price
# 0                                     9.543373       425.0
# 1                                     3.431348       510.0
# 2                                    10.037550       425.0
# 3                                     6.446263       375.0
# 4                                     9.419477       475.0
# ...                                        ...         ...
# 3076                                 54.130591       850.0
# 3077                                 11.078158      1100.0
# 3080                                  5.051280       550.0
# 3081                                 13.587161       625.0
# 3082                                133.746801       300.0
#
# [2852 rows x 8 columns]

# %%
file_path2 = '../data/curated/increase_rates.csv' 
df2 = pd.read_csv(file_path2)
desired_columns = [
    'District', 'Mar 2017 to Jun 2017 % Increase', 'Jun 2017 to Sep 2017 % Increase', 
    'Sep 2017 to Dec 2017 % Increase', 'Dec 2017 to Mar 2018 % Increase', 
    'Mar 2018 to Jun 2018 % Increase', 'Jun 2018 to Sep 2018 % Increase', 
    'Sep 2018 to Dec 2018 % Increase', 'Dec 2018 to Mar 2019 % Increase', 
    'Mar 2019 to Jun 2019 % Increase', 'Jun 2019 to Sep 2019 % Increase', 
    'Sep 2019 to Dec 2019 % Increase', 'Dec 2019 to Mar 2020 % Increase', 
    'Mar 2020 to Jun 2020 % Increase', 'Jun 2020 to Sep 2020 % Increase', 
    'Sep 2020 to Dec 2020 % Increase', 'Dec 2020 to Mar 2021 % Increase', 
    'Mar 2021 to Jun 2021 % Increase', 'Jun 2021 to Sep 2021 % Increase', 
    'Sep 2021 to Dec 2021 % Increase', 'Dec 2021 to Mar 2022 % Increase', 
    'Mar 2022 to Jun 2022 % Increase', 'Jun 2022 to Sep 2022 % Increase', 
    'Sep 2022 to Dec 2022 % Increase', 'Dec 2022 to Mar 2023 % Increase'
]

df2_selected = df2[desired_columns]

df2_selected
# Out:
#           District  Mar 2017 to Jun 2017 % Increase  \
# 0      Albert Park                         3.000000
# 1      Middle Park                         3.000000
# 2    West St Kilda                         3.000000
# 3         Armadale                         4.651163
# 4    Carlton North                         2.586207
# ..             ...                              ...
# 210      Traralgon                         5.555556
# 211    Wanagaratta                         2.702703
# 212       Warragul                         0.000000
# 213    Warrnambool                         0.000000
# 214        Wodonga                         2.631579
#
#      Jun 2017 to Sep 2017 % Increase  Sep 2017 to Dec 2017 % Increase  \
# 0                          -2.912621                         5.000000
# 1                          -2.912621                         5.000000
# 2                          -2.912621                         5.000000
# 3                           0.000000                         2.222222
# 4                           0.840336                         0.000000
# ..                               ...                              ...
# 210                         0.000000                         0.000000
# 211                         0.000000                         0.000000
# 212                         5.000000                         2.380952
# 213                         5.000000                         0.000000
# 214                         2.564103                         2.500000
#
#      Dec 2017 to Mar 2018 % Increase  Mar 2018 to Jun 2018 % Increase  \
# 0                          -4.761905                         3.000000
# 1                          -4.761905                         3.000000
# 2                          -4.761905                         3.000000
# 3                          -6.521739                         4.651163
# 4                          -3.333333                         2.586207
# ..                               ...                              ...
# 210                        -5.263158                         5.555556
# 211                        -2.631579                         2.702703
# 212                        -6.976744                         0.000000
# 213                        -4.761905                         0.000000
# 214                        -7.317073                         2.631579
#
#      Jun 2018 to Sep 2018 % Increase  Sep 2018 to Dec 2018 % Increase  \
# 0                          -2.912621                         5.000000
# 1                          -2.912621                         5.000000
# 2                          -2.912621                         5.000000
# 3                           0.000000                         2.222222
# 4                           0.840336                         0.000000
# ..                               ...                              ...
# 210                         0.000000                         0.000000
# 211                         0.000000                         0.000000
# 212                         5.000000                         2.380952
# 213                         5.000000                         0.000000
# 214                         2.564103                         2.500000
#
#      Dec 2018 to Mar 2019 % Increase  Mar 2019 to Jun 2019 % Increase  ...  \
# 0                          -4.761905                         3.000000  ...
# 1                          -4.761905                         3.000000  ...
# 2                          -4.761905                         3.000000  ...
# 3                          -6.521739                         4.651163  ...
# 4                          -3.333333                         2.586207  ...
# ..                               ...                              ...  ...
# 210                        -5.263158                         5.555556  ...
# 211                        -2.631579                         2.702703  ...
# 212                        -6.976744                         0.000000  ...
# 213                        -4.761905                         0.000000  ...
# 214                        -7.317073                         2.631579  ...
#
#      Sep 2020 to Dec 2020 % Increase  Dec 2020 to Mar 2021 % Increase  \
# 0                           5.000000                        -4.761905
# 1                           5.000000                        -4.761905
# 2                           5.000000                        -4.761905
# 3                           2.222222                        -6.521739
# 4                           0.000000                        -3.333333
# ..                               ...                              ...
# 210                         0.000000                        -5.263158
# 211                         0.000000                        -2.631579
# 212                         2.380952                        -6.976744
# 213                         0.000000                        -4.761905
# 214                         2.500000                        -7.317073
#
#      Mar 2021 to Jun 2021 % Increase  Jun 2021 to Sep 2021 % Increase  \
# 0                           3.000000                        -2.912621
# 1                           3.000000                        -2.912621
# 2                           3.000000                        -2.912621
# 3                           4.651163                         0.000000
# 4                           2.586207                         0.840336
# ..                               ...                              ...
# 210                         5.555556                         0.000000
# 211                         2.702703                         0.000000
# 212                         0.000000                         5.000000
# 213                         0.000000                         5.000000
# 214                         2.631579                         2.564103
#
#      Sep 2021 to Dec 2021 % Increase  Dec 2021 to Mar 2022 % Increase  \
# 0                           5.000000                        -4.761905
# 1                           5.000000                        -4.761905
# 2                           5.000000                        -4.761905
# 3                           2.222222                        -6.521739
# 4                           0.000000                        -3.333333
# ..                               ...                              ...
# 210                         0.000000                        -5.263158
# 211                         0.000000                        -2.631579
# 212                         2.380952                        -6.976744
# 213                         0.000000                        -4.761905
# 214                         2.500000                        -7.317073
#
#      Mar 2022 to Jun 2022 % Increase  Jun 2022 to Sep 2022 % Increase  \
# 0                           3.000000                        -2.912621
# 1                           3.000000                        -2.912621
# 2                           3.000000                        -2.912621
# 3                           4.651163                         0.000000
# 4                           2.586207                         0.840336
# ..                               ...                              ...
# 210                         5.555556                         0.000000
# 211                         2.702703                         0.000000
# 212                         0.000000                         5.000000
# 213                         0.000000                         5.000000
# 214                         2.631579                         2.564103
#
#      Sep 2022 to Dec 2022 % Increase  Dec 2022 to Mar 2023 % Increase
# 0                           5.000000                         3.809524
# 1                           5.000000                         3.809524
# 2                           5.000000                         3.809524
# 3                           2.222222                         6.521739
# 4                           0.000000                         3.333333
# ..                               ...                              ...
# 210                         0.000000                         1.315789
# 211                         0.000000                         0.000000
# 212                         2.380952                         2.325581
# 213                         0.000000                         0.000000
# 214                         2.500000                         0.000000
#
# [215 rows x 25 columns]

# %%
output_file_path = '../data/curated/selected_columns_file.csv' 
df2_selected.to_csv(output_file_path, index=False)

print("文件已成功清理并保存为:", output_file_path)
# Out:
# 文件已成功清理并保存为: ../data/curated/selected_columns_file.csv

# %%
# LOAD csv
file_path3 = '../data/curated/cleaned_data_2.csv'  
df3 = pd.read_csv(file_path3)

# %%
df3 = df3.rename(columns={'name': 'Property Name'}).drop(columns=['rent'])

df3
# Out:
#                                           Property Name  bedrooms  bathrooms  \
# 0                 17/25 Williams Road, Prahran VIC 3181         1          1
# 1                    6/137 Coppin St, Richmond VIC 3121         1          1
# 2     410/378-390 St Georges Road, Fitzroy North VIC...         1          1
# 3                 205/6 Joseph Road, Footscray VIC 3011         1          1
# 4                      8/7 Docker St, Richmond VIC 3121         1          1
# ...                                                 ...       ...        ...
# 4259               13 Adelaide St, Blairgowrie VIC 3942         5          3
# 4260                     160 Moore rd, Sunbury VIC 3429         5          2
# 4261                    4 Vital drive, Tarneit VIC 3029         5          2
# 4262             14 Sheffield Way, Keysborough VIC 3173         5          2
# 4263               4 Ocean Park Drive, Marengo VIC 3233         5          2
#
#       parking_spots
# 0                 0
# 1                 0
# 2                 1
# 3                 1
# 4                 1
# ...             ...
# 4259              1
# 4260              0
# 4261              1
# 4262              1
# 4263              1
#
# [4264 rows x 4 columns]

# %%
# needed row
df3_subset = df3[['Property Name', 'bedrooms', 'bathrooms', 'parking_spots']]


df_cleaned = df_no_outliers.merge(df3_subset, on='Property Name', how='left')


df_cleaned
# Out:
#                                  Property Name  Property Latitude  \
# 0           6/137 Coppin St, Richmond VIC 3121         -37.820283
# 1        205/6 Joseph Road, Footscray VIC 3011         -37.798238
# 2             8/7 Docker St, Richmond VIC 3121         -37.823681
# 3         8/51 Kooyong Road, Armadale VIC 3143         -37.862342
# 4     10/54 Rockley Road, South Yarra VIC 3141         -37.835164
# ...                                        ...                ...
# 2847      13 Adelaide St, Blairgowrie VIC 3942         -38.367311
# 2848            160 Moore rd, Sunbury VIC 3429         -37.608981
# 2849           4 Vital drive, Tarneit VIC 3029         -37.858304
# 2850    14 Sheffield Way, Keysborough VIC 3173         -38.000807
# 2851      4 Ocean Park Drive, Marengo VIC 3233         -38.771375
#
#       Property Longitude  Station Distance (km)  School Distance (km)  \
# 0             145.003572               0.882026              0.326233
# 1             144.914181               0.990486              0.723669
# 2             144.997096               0.308573              0.676342
# 3             145.019539               0.658460              0.917637
# 4             145.000360               0.785119              0.360197
# ...                  ...                    ...                   ...
# 2847          144.785258              34.419625              3.431329
# 2848          144.711509               2.216868              1.528344
# 2849          144.647505               3.788183              1.152332
# 2850          145.149657               4.452369              0.542452
# 2851          143.657868              47.991571              1.994837
#
#                            SA2_NAME21  \
# 0         Richmond (South) - Cremorne
# 1                           Footscray
# 2         Richmond (South) - Cremorne
# 3                            Armadale
# 4                 South Yarra - North
# ...                               ...
# 2847                     Point Nepean
# 2848                  Sunbury - South
# 2849  Tarneit (West) - Mount Cottrell
# 2850              Keysborough - South
# 2851                            Otway
#
#       Distance to Closest Shopping Center (km)  rent price  bedrooms  \
# 0                                     9.543373       425.0       1.0
# 1                                     3.431348       510.0       1.0
# 2                                    10.037550       425.0       1.0
# 3                                     6.446263       375.0       1.0
# 4                                     9.419477       475.0       1.0
# ...                                        ...         ...       ...
# 2847                                 54.130591       850.0       5.0
# 2848                                 11.078158      1100.0       5.0
# 2849                                  5.051280       550.0       5.0
# 2850                                 13.587161       625.0       5.0
# 2851                                133.746801       300.0       5.0
#
#       bathrooms  parking_spots
# 0           1.0            0.0
# 1           1.0            1.0
# 2           1.0            1.0
# 3           1.0            1.0
# 4           1.0            1.0
# ...         ...            ...
# 2847        3.0            1.0
# 2848        2.0            0.0
# 2849        2.0            1.0
# 2850        2.0            1.0
# 2851        2.0            1.0
#
# [2852 rows x 11 columns]

# %%
df_cleaned = df_cleaned.dropna(subset=['bathrooms'])

df_cleaned
# Out:
#                                  Property Name  Property Latitude  \
# 0           6/137 Coppin St, Richmond VIC 3121         -37.820283
# 1        205/6 Joseph Road, Footscray VIC 3011         -37.798238
# 2             8/7 Docker St, Richmond VIC 3121         -37.823681
# 3         8/51 Kooyong Road, Armadale VIC 3143         -37.862342
# 4     10/54 Rockley Road, South Yarra VIC 3141         -37.835164
# ...                                        ...                ...
# 2847      13 Adelaide St, Blairgowrie VIC 3942         -38.367311
# 2848            160 Moore rd, Sunbury VIC 3429         -37.608981
# 2849           4 Vital drive, Tarneit VIC 3029         -37.858304
# 2850    14 Sheffield Way, Keysborough VIC 3173         -38.000807
# 2851      4 Ocean Park Drive, Marengo VIC 3233         -38.771375
#
#       Property Longitude  Station Distance (km)  School Distance (km)  \
# 0             145.003572               0.882026              0.326233
# 1             144.914181               0.990486              0.723669
# 2             144.997096               0.308573              0.676342
# 3             145.019539               0.658460              0.917637
# 4             145.000360               0.785119              0.360197
# ...                  ...                    ...                   ...
# 2847          144.785258              34.419625              3.431329
# 2848          144.711509               2.216868              1.528344
# 2849          144.647505               3.788183              1.152332
# 2850          145.149657               4.452369              0.542452
# 2851          143.657868              47.991571              1.994837
#
#                            SA2_NAME21  \
# 0         Richmond (South) - Cremorne
# 1                           Footscray
# 2         Richmond (South) - Cremorne
# 3                            Armadale
# 4                 South Yarra - North
# ...                               ...
# 2847                     Point Nepean
# 2848                  Sunbury - South
# 2849  Tarneit (West) - Mount Cottrell
# 2850              Keysborough - South
# 2851                            Otway
#
#       Distance to Closest Shopping Center (km)  rent price  bedrooms  \
# 0                                     9.543373       425.0       1.0
# 1                                     3.431348       510.0       1.0
# 2                                    10.037550       425.0       1.0
# 3                                     6.446263       375.0       1.0
# 4                                     9.419477       475.0       1.0
# ...                                        ...         ...       ...
# 2847                                 54.130591       850.0       5.0
# 2848                                 11.078158      1100.0       5.0
# 2849                                  5.051280       550.0       5.0
# 2850                                 13.587161       625.0       5.0
# 2851                                133.746801       300.0       5.0
#
#       bathrooms  parking_spots
# 0           1.0            0.0
# 1           1.0            1.0
# 2           1.0            1.0
# 3           1.0            1.0
# 4           1.0            1.0
# ...         ...            ...
# 2847        3.0            1.0
# 2848        2.0            0.0
# 2849        2.0            1.0
# 2850        2.0            1.0
# 2851        2.0            1.0
#
# [2808 rows x 11 columns]

# %%
output_file_path = '../data/curated/df_cleaned.csv'
df_cleaned.to_csv(output_file_path, index=False)

print("文件已成功清理并保存为:", output_file_path)
# Out:
# 文件已成功清理并保存为: ../data/curated/df_cleaned.csv
